# %% [markdown]
# ### **Опис змінних**
#
# Цей опис є і на Kaggle, але ми переклали для вашої зручності і аби він був у вас перед очима під час роботи над проєктом.
#
# #### **Дані про клієнта банку**:
# 1. **age** – вік клієнта (числова змінна).
# 2. **job** – вид зайнятості (категоріальна змінна: `admin.`, `blue-collar`, `entrepreneur`, `housemaid`, `management`, `retired`, `self-employed`, `services`, `student`, `technician`, `unemployed`, `unknown`).
# 3. **marital** – сімейний стан (категоріальна змінна: `divorced`, `married`, `single`, `unknown`; примітка: `divorced` означає розлучений або вдівець/вдова).
# 4. **education** – рівень освіти (категоріальна змінна: `basic.4y`, `basic.6y`, `basic.9y`, `high.school`, `illiterate`, `professional.course`, `university.degree`, `unknown`).
# 5. **default** – чи є у клієнта прострочений кредит? (категоріальна змінна: `no`, `yes`, `unknown`).
# 6. **housing** – чи має клієнт іпотечний кредит? (категоріальна змінна: `no`, `yes`, `unknown`).
# 7. **loan** – чи має клієнт споживчий кредит? (категоріальна змінна: `no`, `yes`, `unknown`).
#
# #### **Дані про останній контакт у межах поточної маркетингової кампанії**:
# 8. **contact** – тип зв’язку при останньому контакті (категоріальна змінна: `cellular`, `telephone`).
# 9. **month** – місяць останнього контакту (категоріальна змінна: `jan`, `feb`, `mar`, …, `nov`, `dec`).
# 10. **day_of_week** – день тижня останнього контакту (категоріальна змінна: `mon`, `tue`, `wed`, `thu`, `fri`).
# 11. **duration** – тривалість останнього контакту в секундах (числова змінна).
#    ⚠ **Важлива примітка**: ця змінна має суттєвий вплив на цільову змінну (наприклад, якщо duration = 0, то y = `no`). Однак значення duration невідоме до здійснення дзвінка. Крім того, після завершення дзвінка значення y вже відоме. Тому цю змінну варто використовувати лише для порівняння моделей, але не включати у фінальну передбачувальну модель.
#
# #### **Інші атрибути**:
# 12. **campaign** – кількість контактів у межах поточної кампанії для цього клієнта (числова змінна, включає останній контакт).
# 13. **pdays** – кількість днів, що минули з моменту останнього контакту клієнта у попередній кампанії (числова змінна; значення 999 означає, що клієнт раніше не контактувався).
# 14. **previous** – кількість контактів, здійснених до цієї кампанії для цього клієнта (числова змінна).
# 15. **poutcome** – результат попередньої маркетингової кампанії (категоріальна змінна: `failure`, `nonexistent`, `success`).
#
# #### **Атрибути соціально-економічного контексту**:
# 16. **emp.var.rate** – темп зміни зайнятості (щоквартальний показник, числова змінна).
# 17. **cons.price.idx** – індекс споживчих цін (щомісячний показник, числова змінна).
# 18. **cons.conf.idx** – індекс довіри споживачів (щомісячний показник, числова змінна).
# 19. **euribor3m** – ставка Euribor на 3 місяці (щоденний показник, числова змінна).
# 20. **nr.employed** – кількість працевлаштованих осіб (щоквартальний показник, числова змінна).
#
# #### **Цільова змінна**:
# 21. **y** – чи підписав клієнт строковий депозит? (бінарна змінна: `yes`, `no`).

# %%
import pandas as pd
import numpy as np
from pandas.api.types import is_object_dtype
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings
import visualization as visual

# %% [markdown]
# ## **Exploratory Data Analysis**
# ### + Hypothesis

# %%
df = pd.read_csv('bank-additional-full.csv', sep=';')
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %%
def EDA(df):
    total_na = df.isna().sum().sum()
    print('Dimensions: %d rows, %d columns' % (df.shape[0], df.shape[1]))
    print("Total NA's : %d " % (total_na))
    summary = pd.DataFrame({
        "Data Type": df.dtypes,
        "Count Unique": df.nunique(),
        "NA Values": df.isna().sum(),
        "Values": [
            df[col].unique() if is_object_dtype(df[col]) | (df[col].nunique()<=10) else "NA"
            for col in df.columns
            ]
    })
    display(summary)
    display(df.describe())
    print(df.dtypes.value_counts())
    total_memory = df.memory_usage(deep=True).sum()
    print(f"Memory usage: {total_memory / 1024:.2f} KB")

EDA(df)
# Out:
# Dimensions: 41188 rows, 21 columns
# Total NA's : 0
#                Data Type  Count Unique  NA Values  \
# age                int64            78          0
# job               object            12          0
# marital           object             4          0
# education         object             8          0
# default           object             3          0
# housing           object             3          0
# loan              object             3          0
# contact           object             2          0
# month             object            10          0
# day_of_week       object             5          0
# duration           int64          1544          0
# campaign           int64            42          0
# pdays              int64            27          0
# previous           int64             8          0
# poutcome          object             3          0
# emp.var.rate     float64            10          0
# cons.price.idx   float64            26          0
# cons.conf.idx    float64            26          0
# euribor3m        float64           316          0
# nr.employed      float64            11          0
# y                 object             2          0
#
#                                                            Values
# age                                                            NA
# job             [housemaid, services, admin., blue-collar, tec...
# marital                      [married, single, divorced, unknown]
# education       [basic.4y, high.school, basic.6y, basic.9y, pr...
# default                                        [no, unknown, yes]
# housing                                        [no, yes, unknown]
# loan                                           [no, yes, unknown]
# contact                                     [telephone, cellular]
# month           [may, jun, jul, aug, oct, nov, dec, mar, apr, ...
# day_of_week                             [mon, tue, wed, thu, fri]
# duration                                                       NA
# campaign                                                       NA
# pdays                                                          NA
# previous                                 [0, 1, 2, 3, 4, 5, 6, 7]
# poutcome                          [nonexistent, failure, success]
# emp.var.rate    [1.1, 1.4, -0.1, -0.2, -1.8, -2.9, -3.4, -3.0,...
# cons.price.idx                                                 NA
# cons.conf.idx                                                  NA
# euribor3m                                                      NA
# nr.employed                                                    NA
# y                                                       [no, yes]
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000
# object     11
# int64       5
# float64     5
# Name: count, dtype: int64
# Memory usage: 27447.61 KB

# %%
X = df.drop('y', axis=1)
y = df.y

input_cols = list(df.columns)[1:-1]
target_col = 'y'
categorical_features = X.select_dtypes(include='object').columns.tolist()
numerical_features = X.select_dtypes(include=np.number).columns.tolist()[:-1]

# %%
df_yes = df[df['y'] == "yes"]
df_no = df[df['y'] == "no"]
display(df_yes.shape)
display(df_no.shape)
# Out:
# (4640, 21)
# (36548, 21)

# %%
for col in categorical_features:
    plt.figure(figsize=(14,4))
    sns.countplot(x=col, data=df, color = 'purple')
    plt.title(f'Розподіл фічі {col}')
    plt.show()

for col in numerical_features:
    visual.dist_box(df, col)

# %%
corr = visual.plot_filtered_correlation_matrix(df_yes, numerical_features, 0.5, 0.9999)

# %%
mask = np.triu(np.ones(corr.shape), k=1).astype(bool)
valid_corr = (
    corr.where(mask)
        .stack()
        .loc[lambda s: s.abs().between(0.5, 0.99)]
        .sort_values(key=abs, ascending=False)
)
valid_corr
# Out:
# emp.var.rate  euribor3m         0.926117
# pdays         previous         -0.728953
# emp.var.rate  cons.price.idx    0.660341
# duration      emp.var.rate      0.503056
# dtype: float64

# %% [markdown]
# У даних клієнтів, які все ж взяли строковий депозит, значно корелюють такі числові колонки:
# *   `euribor3m`	та `emp.var.rate`
# *   `nr.employed` та	`euribor3m`
# *   `emp.var.rate` та `nr.employed`
# *   `cons.price.idx` та `emp.var.rate`
# *   `pdays` та `previous`

# %% [markdown]
# ### Як корелюють деякі ознаки між собою

# %%
display(df_yes.groupby(by = ['job','marital']).age.describe())
display(df_no.groupby(by = ['job','marital']).age.describe())
# Out:
#                         count       mean        std   min    25%   50%    75%  \
# job           marital
# admin.        divorced  132.0  44.878788   8.452860  28.0  38.75  44.5  52.00
#               married   652.0  41.386503  10.249019  23.0  33.00  39.0  49.00
#               single    566.0  32.404594   6.957310  21.0  28.00  31.0  35.00
#               unknown     2.0  42.500000   9.192388  36.0  39.25  42.5  45.75
# blue-collar   divorced   53.0  42.037736   9.242382  28.0  34.00  40.0  50.00
#               married   421.0  41.363420   9.169488  21.0  33.00  41.0  49.00
#               single    161.0  32.652174   7.190498  22.0  27.00  31.0  36.00
#               unknown     3.0  37.000000  13.228757  27.0  29.50  32.0  42.00
# entrepreneur  divorced   14.0  44.857143   9.113449  31.0  35.50  46.5  51.50
#               married    88.0  43.090909   9.395079  27.0  36.75  42.0  48.00
#               single     21.0  35.666667   8.901311  24.0  30.00  33.0  36.00
#               unknown     1.0  31.000000        NaN  31.0  31.00  31.0  31.00
# housemaid     divorced   16.0  57.000000  16.911535  34.0  39.75  56.0  67.00
#               married    74.0  54.256757  13.619145  27.0  46.00  53.5  62.75
#               single     16.0  40.875000   8.693868  29.0  34.00  41.5  47.00
# management    divorced   39.0  46.692308  11.180702  33.0  36.00  48.0  54.50
#               married   226.0  44.756637  10.191416  25.0  36.00  43.0  52.00
#               single     63.0  33.285714   7.412780  23.0  28.00  32.0  37.00
# retired       divorced   92.0  72.739130  11.407410  42.0  63.25  74.5  81.25
#               married   329.0  67.033435   9.214687  33.0  60.00  66.0  74.00
#               single     12.0  67.500000  11.859020  44.0  63.25  68.5  73.75
#               unknown     1.0  66.000000        NaN  66.0  66.00  66.0  66.00
# self-employed divorced   16.0  41.875000   9.938980  25.0  38.75  44.5  48.00
#               married    82.0  41.036585   9.279534  26.0  34.00  40.0  47.00
#               single     51.0  31.921569   5.778730  21.0  28.50  31.0  35.50
# services      divorced   33.0  43.484848   7.925912  25.0  40.00  44.0  47.00
#               married   166.0  38.379518   8.264231  23.0  32.00  37.0  44.00
#               single    124.0  31.024194   6.766084  21.0  26.00  30.0  33.00
# student       divorced    3.0  35.666667   2.309401  33.0  35.00  37.0  37.00
#               married     8.0  31.250000   3.011881  25.0  30.00  32.0  33.00
#               single    264.0  24.481061   4.584610  17.0  21.00  24.0  27.00
# technician    divorced   65.0  40.738462   8.273219  26.0  34.00  39.0  46.00
#               married   384.0  41.398438   9.450992  23.0  34.00  39.0  50.00
#               single    279.0  32.078853   5.821155  20.0  28.00  31.0  34.00
#               unknown     2.0  30.000000   0.000000  30.0  30.00  30.0  30.00
# unemployed    divorced   10.0  47.900000  10.969149  31.0  38.50  55.5  56.00
#               married    86.0  41.941860  10.023918  24.0  34.25  41.0  49.00
#               single     48.0  32.062500   7.708537  21.0  26.00  31.5  35.25
# unknown       divorced    3.0  76.333333   8.082904  67.0  74.00  81.0  81.00
#               married    16.0  58.750000  11.054411  34.0  55.00  58.0  64.25
#               single     15.0  30.000000   6.824326  24.0  24.50  27.0  34.00
#               unknown     3.0  40.666667   7.505553  32.0  38.50  45.0  45.00
#
#                          max
# job           marital
# admin.        divorced  66.0
#               married   72.0
#               single    59.0
#               unknown   49.0
# blue-collar   divorced  59.0
#               married   70.0
#               single    53.0
#               unknown   52.0
# entrepreneur  divorced  59.0
#               married   69.0
#               single    57.0
#               unknown   31.0
# housemaid     divorced  83.0
#               married   85.0
#               single    58.0
# management    divorced  80.0
#               married   77.0
#               single    60.0
# retired       divorced  92.0
#               married   98.0
#               single    86.0
#               unknown   66.0
# self-employed divorced  60.0
#               married   60.0
#               single    51.0
# services      divorced  57.0
#               married   59.0
#               single    56.0
# student       divorced  37.0
#               married   35.0
#               single    47.0
# technician    divorced  61.0
#               married   70.0
#               single    55.0
#               unknown   30.0
# unemployed    divorced  58.0
#               married   60.0
#               single    66.0
# unknown       divorced  81.0
#               married   78.0
#               single    42.0
#               unknown   45.0
#                          count       mean        std   min    25%   50%  \
# job           marital
# admin.        divorced  1148.0  43.098432   8.496570  25.0  36.00  43.0
#               married   4601.0  40.148663   8.654834  21.0  33.00  39.0
#               single    3309.0  33.858265   6.841409  20.0  29.00  32.0
#               unknown     12.0  34.666667   5.210712  29.0  33.25  34.0
# blue-collar   divorced   675.0  42.903704   8.099048  24.0  37.00  42.0
#               married   6266.0  40.857804   8.479187  20.0  34.00  40.0
#               single    1664.0  33.409255   7.202437  20.0  28.00  32.0
#               unknown     11.0  42.818182  10.796464  27.0  36.00  38.0
# entrepreneur  divorced   165.0  44.042424   8.396683  27.0  37.00  43.0
#               married    983.0  42.477111   8.623090  23.0  36.00  42.0
#               single     182.0  35.472527   7.704258  20.0  30.25  34.0
#               unknown      2.0  35.500000   6.363961  31.0  33.25  35.5
# housemaid     divorced   145.0  48.806897  10.477023  31.0  41.00  50.0
#               married    703.0  44.849218   9.562958  24.0  38.00  45.0
#               single     103.0  38.087379   9.016441  21.0  31.00  37.0
#               unknown      3.0  40.000000  12.124356  33.0  33.00  33.0
# management    divorced   292.0  46.123288   8.008492  29.0  39.75  47.0
#               married   1863.0  43.634997   8.516547  24.0  36.50  43.0
#               single     438.0  34.070776   7.219793  21.0  29.00  32.0
#               unknown      3.0  51.000000  12.124356  37.0  47.50  58.0
# retired       divorced   256.0  61.480469  11.282800  37.0  54.75  59.0
#               married    945.0  60.019048   8.920058  32.0  56.00  58.0
#               single      81.0  53.938272  12.260042  23.0  47.00  57.0
#               unknown      4.0  59.750000   4.272002  57.0  57.00  58.0
# self-employed divorced   117.0  42.871795   8.182760  25.0  36.00  43.0
#               married    822.0  42.349148   9.111757  25.0  35.00  41.0
#               single     328.0  33.783537   7.415504  21.0  28.00  32.0
#               unknown      5.0  39.400000   9.813256  31.0  31.00  35.0
# services      divorced   499.0  41.991984   8.544940  25.0  35.00  42.0
#               married   2128.0  39.992951   8.596008  22.0  33.00  39.0
#               single    1013.0  32.159921   7.156501  20.0  27.00  31.0
#               unknown      6.0  40.000000   9.715966  33.0  33.25  34.5
# student       divorced     6.0  34.500000   4.086563  27.0  34.00  35.0
#               married     33.0  30.484848   4.416738  24.0  28.00  31.0
#               single     560.0  26.062500   4.868359  17.0  23.00  25.0
#               unknown      1.0  30.000000        NaN  30.0  30.00  30.0
# technician    divorced   709.0  42.173484   8.181699  24.0  35.00  42.0
#               married   3286.0  40.686245   8.629769  22.0  34.00  39.0
#               single    2008.0  33.950697   6.414208  20.0  30.00  33.0
#               unknown     10.0  33.300000   9.499123  25.0  29.00  29.5
# unemployed    divorced   114.0  42.140351   8.227815  29.0  35.00  41.0
#               married    548.0  41.636861   8.670564  21.0  35.00  42.0
#               single     203.0  33.536946   7.394296  21.0  29.00  32.0
#               unknown      5.0  47.200000   5.718391  37.0  49.00  50.0
# unknown       divorced    10.0  43.300000  10.750194  30.0  38.00  40.0
#               married    218.0  47.532110   8.722627  29.0  43.00  47.0
#               single      59.0  38.288136  10.728709  24.0  29.00  36.0
#               unknown      6.0  40.166667   9.988327  32.0  32.00  36.5
#
#                           75%   max
# job           marital
# admin.        divorced  50.00  70.0
#               married   46.00  72.0
#               single    37.00  60.0
#               unknown   34.50  49.0
# blue-collar   divorced  49.00  71.0
#               married   47.00  80.0
#               single    38.00  58.0
#               unknown   53.00  58.0
# entrepreneur  divorced  52.00  59.0
#               married   49.00  69.0
#               single    41.00  57.0
#               unknown   37.75  40.0
# housemaid     divorced  55.00  85.0
#               married   52.00  85.0
#               single    42.50  59.0
#               unknown   43.50  54.0
# management    divorced  53.00  64.0
#               married   50.00  76.0
#               single    37.00  77.0
#               unknown   58.00  58.0
# retired       divorced  68.25  95.0
#               married   63.00  94.0
#               single    59.00  85.0
#               unknown   60.75  66.0
# self-employed divorced  49.00  61.0
#               married   50.00  71.0
#               single    37.00  60.0
#               unknown   50.00  50.0
# services      divorced  48.00  59.0
#               married   47.00  69.0
#               single    36.00  59.0
#               unknown   47.75  53.0
# student       divorced  37.50  38.0
#               married   33.00  41.0
#               single    28.25  46.0
#               unknown   30.00  30.0
# technician    divorced  48.00  60.0
#               married   48.00  69.0
#               single    37.00  59.0
#               unknown   33.00  55.0
# unemployed    divorced  47.75  64.0
#               married   49.00  64.0
#               single    37.00  66.0
#               unknown   50.00  50.0
# unknown       divorced  46.25  66.0
#               married   53.00  78.0
#               single    44.00  61.0
#               unknown   47.00  55.0

# %%
visual.bi_countplot_target(df_no, df_yes, 'job','marital', 'Клієнти, що оформили строковий депозит', 'Клієнти, що НЕ оформили строковий депозит')
# Out:
# NORMALIZED DISTRIBUTION OF VALUES FOR CATEGORY: JOB
# COUNT OF VALUES FOR CATEGORY: JOB

# %% [markdown]
# 1.   Самотрі студенти (student single) та заміжні адміни (admin married) схильні взяти строковий депозит
# 2.   Робітники (blue-collar) та працівники сфери послуг (services) частіше не погоджуються на строковий депозит
# 3.   Самотні або розлучені техніки (technician single\divorced) частіше не беруть строкові депозити

# %%
visual.bi_countplot_target(df_no, df_yes, 'education','default', 'Клієнти, що оформили строковий депозит', 'Клієнти, що НЕ оформили строковий депозит')
# Out:
# NORMALIZED DISTRIBUTION OF VALUES FOR CATEGORY: EDUCATION
# COUNT OF VALUES FOR CATEGORY: EDUCATION

# %%
display(df_yes[['default', 'housing', 'loan']].apply(pd.Series.value_counts))
display(df_no[['default', 'housing', 'loan']].apply(pd.Series.value_counts))
# Out:
#          default  housing  loan
# no        4197.0     2026  3850
# unknown    443.0      107   107
# yes          NaN     2507   683
#          default  housing   loan
# no         28391    16596  30100
# unknown     8154      883    883
# yes            3    19069   5565

# %% [markdown]
# 1.   Клієнтам, що мають прострочений кредит скоріше за все строковий депозит не пропонують
# 2.   Якщо клієнт має університетський ступінь (univesity.degree), то він скоріше за все візьму строковий депозит

# %%
visual.bi_countplot_target(df_no, df_yes, 'job','day_of_week', 'Клієнти, що оформили строковий депозит', 'Клієнти, що НЕ оформили строковий депозит')
# Out:
# NORMALIZED DISTRIBUTION OF VALUES FOR CATEGORY: JOB
# COUNT OF VALUES FOR CATEGORY: JOB

# %% [markdown]
# 1.   Якщо адмінам (admin) дзвонити в пятницю, скоріше за все клієнт не візьме строковий депозит і для більшої вірогідності позитивного результату, краще дзвонити їм у середу чи четвер
# 2.   Техніки (technician) скоріше візьмуть депозит у пятницю, а у четвер - найменш сприятливий для цього день
# 3.   Суттєвої різниці немає для інших професій

# %%
print("Кількість записів, де неузгоджені previous та poutcome: ", X[(X['previous'] == 0) & (X['poutcome'] != 'nonexistent')].shape[0])
print("Кількість записів, де неузгоджені pdays та poutcome: ", X[(X['pdays'] == 999) & (X['poutcome'] != 'nonexistent')].shape[0])
# Out:
# Кількість записів, де неузгоджені previous та poutcome:  0
# Кількість записів, де неузгоджені pdays та poutcome:  4110

# %%
print("Кількість записів, де pdays, скоріше за все, не відповідає дійсності: ", X[(X['pdays'] == 999) & (X['previous'] > 0) & (X['poutcome'] != 'nonexistent')].shape[0])
# Out:
# Кількість записів, де pdays, скоріше за все, не відповідає дійсності:  4110

# %% [markdown]
# **В датасеті маємо суперечливі рядки у співвідношенні `pdays|previous|poutcome`.**
#
# Базове правило узгодженості таке:
#
# • якщо `poutcome` = *nonexistent*, то очікуємо `previous` = 0 і `pdays` = 999
#
# • якщо `previous` > 0, то очікуємо pdays у 0-998, а `poutcome` - не *nonexistent*
#
# Бачимо, що в датасеті присутні 4110 (близько 10%) записів, де за `pdays` - клієнт раніше не брав участі у кампаніях (йому ніколи не дзвонили), але при тому по цим записам існує визначене `poutcome` та кількість контактів з клієнтом до поточної кампанії (`previous`) != 0.
#
# Видаляти ці рядки буде "боляче", тому можна зробити подібні значення `pdays` невизначеними і додати флаг на "неузгодженість рядка"

# %% [markdown]
# ## **Проміжні підсумки**
# 1.   **Попередня обробка даних (Preprocessing)**
# *   **Пропущені значення:** Датасет не містить початково значень `NA`, додаткова імпутація не потрібна.
# *   **Аномалії та викиди:** Багато числових ознак мають викиди. Потрібно обробити неузгоджені рядки та заповнити утворені пропуски в `pdays` для сумісності з моделями, які не вміють обробляти `NaN` нативно.
# *   **Дисбаланс класів:** Присутній сильний дисбаланс цільової змінної; варто застосувати техніки балансування.
#
# > Цільовий клас: `y=yes` *(клієнти, які з високою ймовірністю оформлять строковий депозит). Мета — оптимізувати роботу контакт-центру та максимізувати дохід.*
#
# *   **Трансформація ознак:**
#
#     *  Категоріальні змінні: `LabelEncoder`.
#
#     *  Числові змінні: `StandardScaler`
#
# *   **Інженерія ознак (Feature Engineering):** Створення додаткових фічей вручну та генерація поліноміальних ознак.
# ---
# 2.  **Моделювання (Models)**
# *   **Бенчмарк:** Логістична регресія з використанням ознаки `duration`.
# *   **Класичні алгоритми:** Логістична регресія, KNN, Дерево прийняття рішень (Decision Tree).
# *   **Ансамблеві методи:** Градієнтний бустинг (XGBoost, LightGBM).
# ---
#
# 3.   **Оцінка якості (Evaluation)**
# *   **AUC-ROC:** Оцінка загальної роздільної здатності моделі незалежно від обраного порогу (threshold).
# *   **Confusion Matrix:** Детальний аналіз розподілу помилок (`FP`, `FN`) та точності передбачень у розрізі кожного класу.
# *   **F1-Score | Precision | Recall:** Фінальна оцінка якості для бізнесу після вибору конкретного робочого порогу.
